# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/train .csv")

# %%
data.head()
# Out:
#    beds  baths    size size_units  lot_size lot_size_units  zip_code  \
# 0     3    2.5  2590.0       sqft   6000.00           sqft     98144
# 1     4    2.0  2240.0       sqft      0.31           acre     98106
# 2     4    3.0  2040.0       sqft   3783.00           sqft     98107
# 3     4    3.0  3800.0       sqft   5175.00           sqft     98199
# 4     2    2.0  1042.0       sqft       NaN            NaN     98102
#
#        price
# 0   795000.0
# 1   915000.0
# 2   950000.0
# 3  1950000.0
# 4   950000.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['beds'].plot(kind='hist', bins=20, title='beds')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['baths'].plot(kind='hist', bins=20, title='baths')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data.shape
# Out:
# (2016, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   beds            2016 non-null   int64
#  1   baths           2016 non-null   float64
#  2   size            2016 non-null   float64
#  3   size_units      2016 non-null   object
#  4   lot_size        1669 non-null   float64
#  5   lot_size_units  1669 non-null   object
#  6   zip_code        2016 non-null   int64
#  7   price           2016 non-null   float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 126.1+ KB

# %%
for column in data.columns:
    print(data[column].value_counts())
    print("*"*20)
# Out:
# 3     645
# 2     560
# 4     398
# 1     256
# 5     123
# 6      22
# 9       5
# 7       3
# 8       2
# 15      1
# 14      1
# Name: beds, dtype: int64
# ********************
# 2.0    627
# 1.0    493
# 2.5    282
# 3.0    198
# 3.5    179
# 1.5    137
# 4.0     37
# 4.5     21
# 5.0     16
# 5.5     13
# 6.0      5
# 7.0      4
# 8.5      1
# 0.5      1
# 9.0      1
# 6.5      1
# Name: baths, dtype: int64
# ********************
# 2080.0    12
# 1440.0    11
# 1460.0    11
# 1370.0    11
# 1670.0    11
#           ..
# 1548.0     1
# 1174.0     1
# 1865.0     1
# 578.0      1
# 795.0      1
# Name: size, Length: 879, dtype: int64
# ********************
# sqft    2016
# Name: size_units, dtype: int64
# ********************
# 5000.0    61
# 4000.0    45
# 6000.0    38
# 1.0       26
# 4800.0    16
#           ..
# 745.0      1
# 5043.0     1
# 2256.0     1
# 8540.0     1
# 4267.0     1
# Name: lot_size, Length: 959, dtype: int64
# ********************
# sqft    1449
# ...

# %%
data.isna().sum()
# Out:
# beds                0
# baths               0
# size                0
# size_units          0
# lot_size          347
# lot_size_units    347
# zip_code            0
# price               0
# dtype: int64

# %%
data.drop(columns=['lot_size','lot_size_units'],inplace=True)

# %%
data.describe()
# Out:
#               beds        baths          size      zip_code         price
# count  2016.000000  2016.000000   2016.000000   2016.000000  2.016000e+03
# mean      2.857639     2.159970   1735.740575  98123.638889  9.636252e+05
# std       1.255092     1.002023    920.132591     22.650819  9.440954e+05
# min       1.000000     0.500000    250.000000  98101.000000  1.590000e+05
# 25%       2.000000     1.500000   1068.750000  98108.000000  6.017500e+05
# 50%       3.000000     2.000000   1560.000000  98117.000000  8.000000e+05
# 75%       4.000000     2.500000   2222.500000  98126.000000  1.105250e+06
# max      15.000000     9.000000  11010.000000  98199.000000  2.500000e+07
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_17['beds'].plot(kind='hist', bins=20, title='beds')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   beds        2016 non-null   int64
#  1   baths       2016 non-null   float64
#  2   size        2016 non-null   float64
#  3   size_units  2016 non-null   object
#  4   zip_code    2016 non-null   int64
#  5   price       2016 non-null   float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 94.6+ KB

# %%
data['beds'].value_counts()
# Out:
# 3     645
# 2     560
# 4     398
# 1     256
# 5     123
# 6      22
# 9       5
# 7       3
# 8       2
# 15      1
# 14      1
# Name: beds, dtype: int64

# %%
data.head()
# Out:
#    beds  baths    size size_units  zip_code      price
# 0     3    2.5  2590.0       sqft     98144   795000.0
# 1     4    2.0  2240.0       sqft     98106   915000.0
# 2     4    3.0  2040.0       sqft     98107   950000.0
# 3     4    3.0  3800.0       sqft     98199  1950000.0
# 4     2    2.0  1042.0       sqft     98102   950000.0

# %%
data['price_per_sqft'] = data['price'] * 100000 / data['size']

# %%
data['price_per_sqft']
# Out:
# 0       3.069498e+07
# 1       4.084821e+07
# 2       4.656863e+07
# 3       5.131579e+07
# 4       9.117083e+07
#             ...
# 2011    6.642336e+07
# 2012    6.186727e+07
# 2013    5.373832e+07
# 2014    7.421384e+07
# 2015    3.853801e+07
# Name: price_per_sqft, Length: 2016, dtype: float64

# %%
data.describe()
# Out:
#               beds        baths          size      zip_code         price  \
# count  2016.000000  2016.000000   2016.000000   2016.000000  2.016000e+03
# mean      2.857639     2.159970   1735.740575  98123.638889  9.636252e+05
# std       1.255092     1.002023    920.132591     22.650819  9.440954e+05
# min       1.000000     0.500000    250.000000  98101.000000  1.590000e+05
# 25%       2.000000     1.500000   1068.750000  98108.000000  6.017500e+05
# 50%       3.000000     2.000000   1560.000000  98117.000000  8.000000e+05
# 75%       4.000000     2.500000   2222.500000  98126.000000  1.105250e+06
# max      15.000000     9.000000  11010.000000  98199.000000  2.500000e+07
#
#        price_per_sqft
# count    2.016000e+03
# mean     5.915851e+07
# std      8.327952e+07
# min      6.796117e+06
# 25%      4.452221e+07
# 50%      5.529762e+07
# 75%      6.595389e+07
# max      3.424658e+09
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
data.shape
# Out:
# (2016, 7)

# %%
data
# Out:
#       beds  baths    size size_units  zip_code      price  price_per_sqft
# 0        3    2.5  2590.0       sqft     98144   795000.0    3.069498e+07
# 1        4    2.0  2240.0       sqft     98106   915000.0    4.084821e+07
# 2        4    3.0  2040.0       sqft     98107   950000.0    4.656863e+07
# 3        4    3.0  3800.0       sqft     98199  1950000.0    5.131579e+07
# 4        2    2.0  1042.0       sqft     98102   950000.0    9.117083e+07
# ...    ...    ...     ...        ...       ...        ...             ...
# 2011     3    2.0  1370.0       sqft     98112   910000.0    6.642336e+07
# 2012     1    1.0   889.0       sqft     98121   550000.0    6.186727e+07
# 2013     4    2.0  2140.0       sqft     98199  1150000.0    5.373832e+07
# 2014     2    2.0   795.0       sqft     98103   590000.0    7.421384e+07
# 2015     3    2.0  1710.0       sqft     98133   659000.0    3.853801e+07
#
# [2016 rows x 7 columns]
# ...

# %%
data.drop(columns=['price_per_sqft'],inplace=True)

# %%
data.head()
# Out:
#    beds  baths    size size_units  zip_code      price
# 0     3    2.5  2590.0       sqft     98144   795000.0
# 1     4    2.0  2240.0       sqft     98106   915000.0
# 2     4    3.0  2040.0       sqft     98107   950000.0
# 3     4    3.0  3800.0       sqft     98199  1950000.0
# 4     2    2.0  1042.0       sqft     98102   950000.0

# %%
data.to_csv("/content/final_dataset.csv")

# %%
X=data.drop(columns=['price'])
y=data['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (1612, 5)
# (1612,)

# %%
column_trans = make_column_transformer((OneHotEncoder(sparse=False), ['beds']), remainder='passthrough')

# %%
scaler = StandardScaler()

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
import pandas as pd

# Print the data types of all columns in the X DataFrame
print(X.dtypes)

# Print the values in the sqft column
print(X["size_units"])
# Out:
# beds            int64
# baths         float64
# size          float64
# size_units     object
# zip_code        int64
# dtype: object
# 0       sqft
# 1       sqft
# 2       sqft
# 3       sqft
# 4       sqft
#         ...
# 2011    sqft
# 2012    sqft
# 2013    sqft
# 2014    sqft
# 2015    sqft
# Name: size_units, Length: 2016, dtype: object

# %%
X = X.drop("size_units", axis=1)

# %%
if "size_units" in X.columns:
    print("The 'size_units' column exists.")
else:
    print("The 'size_units' column does not exist.")
# Out:
# The 'size_units' column does not exist.

# %%
if "size_units" in X.columns:
    print(f"Data type of 'size_units': {X['size_units'].dtype}")

# %%
if "size_units" in X.columns:
    print(f"Number of missing values in 'size_units': {X['size_units'].isna().sum()}")

# %%
try:
    X["size_units"] = pd.to_numeric(X["size_units"])
    print("Conversion successful.")
except Exception as e:
    print(f"Conversion failed: {e}")
# Out:
# Conversion failed: 'size_units'

# %%
if "size_units" in X.columns:
    X["size_units"] = pd.to_numeric(X["size_units"])
else:
    print("The column 'size_units' does not exist in the DataFrame X.")
# Out:
# The column 'size_units' does not exist in the DataFrame X.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# X being feature matrix
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

lr = LinearRegression()
lr.fit(X_scaled, y)
# Out:
# LinearRegression()

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
import pandas as pd

# %%
pipe = make_pipeline(column_trans,scaler, lr)

# %%
# Print the first few rows of the X_train data
print(X_train.head())

# Check the data types of the X_train data
print(X_train.dtypes)
# Out:
#       beds  baths    size size_units  zip_code
# 1354     3    3.5  1644.0       sqft     98112
# 942      2    1.0  2060.0       sqft     98106
# 1170     1    1.0   513.0       sqft     98121
# 651      2    2.0  1644.0       sqft     98101
# 360      3    3.5  1968.0       sqft     98199
# beds            int64
# baths         float64
# size          float64
# size_units     object
# zip_code        int64
# dtype: object

# %%
X_train.drop(columns=["size_units"], inplace=True)

# %%
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['beds'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
print(pipe.steps)
# Out:
# [('columntransformer', ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder', OneHotEncoder(sparse=False),
#                                  ['beds'])])), ('standardscaler', StandardScaler()), ('linearregression', LinearRegression())]

# %%
y_pred_lr = pipe.predict(X_test)

# %%
r2_score(y_test,y_pred_lr)
# Out:
# 0.5736221106866621

# %%
lasso = Lasso()

# %%
pipe = make_pipeline(column_trans,scaler, lasso)

# %%
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['beds'])])),
#                 ('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
y_pred_lasso = pipe.predict(X_test)
r2_score(y_test,y_pred_lasso)
# Out:
# 0.5746817917322382

# %%
ridge = Ridge()

# %%
pipe = make_pipeline(column_trans,scaler, ridge)

# %%
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['beds'])])),
#                 ('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
y_pred_ridge = pipe.predict(X_test)
r2_score(y_test,y_pred_ridge)
# Out:
# 0.5746884627878556

# %%
print("No Regularization: ", r2_score(y_test,y_pred_lr))
print("Lasso: ", r2_score(y_test,y_pred_lasso))
print("Ridge: ", r2_score(y_test,y_pred_ridge))
# Out:
# No Regularization:  0.5736221106866621
# Lasso:  0.5746817917322382
# Ridge:  0.5746884627878556

# %%
import pickle

# %%
pickle.dump(pipe, open('RidgeModel.pkl','wb'))
